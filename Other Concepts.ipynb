# %%
a = list("python")

a.sort(reverse = True)

print(a)
# Out:
# ['y', 't', 'p', 'o', 'n', 'h']

# %%
#itertools

import itertools

Li1 = [1,2,3,4]

print(list(itertools.permutations(Li1)))
# Out:
# [(1, 2, 3, 4), (1, 2, 4, 3), (1, 3, 2, 4), (1, 3, 4, 2), (1, 4, 2, 3), (1, 4, 3, 2), (2, 1, 3, 4), (2, 1, 4, 3), (2, 3, 1, 4), (2, 3, 4, 1), (2, 4, 1, 3), (2, 4, 3, 1), (3, 1, 2, 4), (3, 1, 4, 2), (3, 2, 1, 4), (3, 2, 4, 1), (3, 4, 1, 2), (3, 4, 2, 1), (4, 1, 2, 3), (4, 1, 3, 2), (4, 2, 1, 3), (4, 2, 3, 1), (4, 3, 1, 2), (4, 3, 2, 1)]

# %%
Li1 = [1,2,3,4]

print(list(itertools.combinations(Li1,2)))
print(list(itertools.combinations(Li1,3)))
print(list(itertools.combinations(Li1,4)))
# Out:
# [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
# [(1, 2, 3), (1, 2, 4), (1, 3, 4), (2, 3, 4)]
# [(1, 2, 3, 4)]

# %%
itertools.

# %%
#music player program


#silkboard to kr puram  ==> 30 mins

#music player

#[1,2,4,5,6,7,3,3,3,4,4,2,2,1,10,10,3,4,5,5,10,8,8,8,9,1]

#recommennd a plylist with minmum number of songs
#recommend a playlist with maximum numbr os songs
#recommend all possible playlist

# %%
#args & kwargs
#dynamic argument passer


def sum_ele(x,y,z = 100):
    return x + y + z

print(sum_ele(10,20))
print(sum_ele(10,20,30))

#Ravi
#30
#60

#Gokul

#130
#60
# Out:
# 130
# 60

# %%
def sum_ele(x,y):
    return x + y

print(sum_ele(10,20))
print(sum_ele(40,50))

# %%
def sum_ele(*args):
    sum = 0
    print(args)
    print(type(args))
    for i in args:
        sum = sum + i
    return sum

print(sum_ele(10,20))
print(sum_ele(10,20,30))
print(sum_ele(10,10,20,30,40,50,100,1000))
# Out:
# (10, 20)
# <class 'tuple'>
# 30
# (10, 20, 30)
# <class 'tuple'>
# 60
# (10, 10, 20, 30, 40, 50, 100, 1000)
# <class 'tuple'>
# 1260

# %%
def sum_ele(**kwargs):
    print(kwargs)
    for i,j in kwargs.items():
        print(i)
        print(j)

print(sum_ele(val1=10,val2=20))
print(sum_ele(val1=10,val2=20,val3=30))
print(sum_ele(val1=10,val2=10,val3=20,val4=30,val5=40,val6=50,val7=100,val8=1000))
# Out:
# {'val1': 10, 'val2': 20}
# val1
# 10
# val2
# 20
# None
# {'val1': 10, 'val2': 20, 'val3': 30}
# val1
# 10
# val2
# 20
# val3
# 30
# None
# {'val1': 10, 'val2': 10, 'val3': 20, 'val4': 30, 'val5': 40, 'val6': 50, 'val7': 100, 'val8': 1000}
# val1
# 10
# val2
# 10
# val3
# 20
# val4
# 30
# val5
# 40
# val6
# 50
# val7
# 100
# val8
# 1000
# None

# %%
class user:
    def __init__(self,**kwargs):
        self.data =kwargs
        
    def getdata(self):
        print(self.data["type"])
        print(self.data["model"])
        print(self.data["year"])
        return self.data["model"]

mycar =user(type ="bwm",model ="new",year=2005)
print(mycar.getdata())

#data = {type :"bwm",model :"new"}
# Out:
# bwm
# new
# 2005
# new

# %%
#Threads ==> small pgms #Concurrent prgm

#fn1 (10 mins)

#fn2 (10 mins)

#fn3 (10 mins)

# %%
from threading import Thread

def func1():
    for i in range(100):
        print("gokul")

        
def func2():
    for i in range(100):
        print("Sarav")
        
def func3():
    for i in range(100):
        print("Ravi")
        

thread1 = Thread(target=func1)
thread2 = Thread(target=func2)
thread3 = Thread(target=func3)

thread1.start()
thread2.start()
thread3.start()
# Out:
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokulSarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokulRavi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
#
#
# gokul
# gokul
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
# Sarav
# Sarav
# gokul
# Sarav
# Sarav
# Saravgokul
# gokul
# gokul
# Sarav
# Sarav
# Ravi
# Ravi
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
#
# Sarav
# SaravRavi
# Ravi
# Ravi
# Ravi
# gokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# SaravRavi
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
#
# Ravi
# Ravi
# Ravigokul
# gokulSarav
# Sarav
# Sarav
#
# Ravi
# Ravi
# RaviSarav
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokulSarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Sarav
#
# Ravi
# Ravi
# Sarav
# gokul
# gokulSarav
# Sarav
# Sarav
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
#
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
#
# gokul
# gokulSarav
# gokul
# gokul
# gokul
#
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# Ravigokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
#
# gokul
# gokul
# gokul
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# RaviSarav
# Ravi
# Ravi
# gokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# SaravRavi
# Ravi
#
# Sarav
# SaravgokulRavi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
#
# gokul
# gokul
# gokul
#
# gokulRavi
# Ravi
# Ravi
# gokul
#
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# gokulRavi
# Ravi
# Ravi
# Ravi
# Ravi
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
#
# Ravi
# Ravi
# Ravi
# Ravi
# gokul
# gokul
# gokul
# gokul
# gokul
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi

# %%
from threading import Thread

def func1():
    for i in range(100):
        print("gokul")

        
def func2():
    for i in range(100):
        print("Sarav")
        
def func3():
    for i in range(100):
        print("Ravi")
        

thread1 = Thread(target=func1)
thread2 = Thread(target=func2)
thread3 = Thread(target=func3)

thread1.start()
thread2.start()

thread1.join()
thread2.join()


thread3.start()
# Out:
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Saravgokul
# gokul
# gokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# Saravgokul
# gokul
# gokul
#
# Sarav
# Sarav
# gokul
# gokul
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# Saravgokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# Sarav
# Saravgokul
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Sarav
#
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Saravgokul
#
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# gokul
# gokulSarav
# Sarav
# Sarav
# Sarav
# gokul
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Saravgokul
# gokul
# gokul
# gokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Saravgokul
# gokul
# gokul
# gokul
# gokul
# gokul
#
# gokul
# gokul
# gokulSarav
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi

# %%
from threading import Thread

def func1():
    for i in range(100):
        print("gokul")

        
def func2():
    for i in range(100):
        print("Sarav")
        
def func3():
    for i in range(100):
        print("Ravi")
        

thread1 = Thread(target=func1)
thread2 = Thread(target=func2)
thread3 = Thread(target=func3)

thread1.start()
thread2.start()
thread1.join()
thread3.start()

print("python welcome bro")
# Out:
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Saravgokul
# gokul
# Sarav
#
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokulSarav
# Sarav
# Sarav
#
# gokul
# gokulSarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
#
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# Saravgokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
#
# gokul
# gokul
# gokul
# gokul
# gokulSarav
# Sarav
# Sarav
# Sarav
#
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# gokulSarav
# Sarav
# gokul
# gokul
#
# Sarav
# Saravgokul
# gokul
# gokul
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# gokul
# gokul
# gokul
# gokul
# gokul
# Sarav
# Sarav
# gokul
# gokul
# SaravRavi
# Ravi
# Ravi
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# python welcome bro
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# SaravRavi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
#
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
# SaravRavi
# Ravi
# Ravi
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
#
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# RaviSarav
# Sarav
# Sarav
# Sarav
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
#
# Ravi
# RaviSarav
# Sarav
# Sarav
# Sarav
#
# Ravi
# Ravi
# Ravi
# Ravi
# Sarav
# Sarav
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# SaravRavi
# Ravi
# Sarav
#
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi
# Ravi

# %%
#https://realpython.com/intro-to-python-threading/

# %%
#iterators


a = iter([1,2,3,4])

print(next(a))
print(next(a))
print(next(a))
print(next(a))
# Out:
# 1
# 2
# 3
# 4

# %%
#generators (iterator + return )
#https://www.geeksforgeeks.org/generators-in-python/

#yield ==> return iteratively

def func():
    yield "no 1"
    yield "no 2"
    yield "no 3"
    
for i in func():
    print(i)
# Out:
# no 1
# no 2
# no 3

# %%
#decorator

#decorator
#one function available with exception or enhancement 

#decorator function
def supporting_func(func):
    def inner_func():
        print("line 1")
        func()
        print("line 2")
    return inner_func

#function that we cant alter #available in some other system or module 
def actual_func():
    print("Actual")
    
actual_func = supporting_func(actual_func)
actual_func()

# %%
#decorator:

#https://www.geeksforgeeks.org/decorators-in-python/

#decorator functionality

def deocrator_function(func):
    def inner_fun():
        print("front wrapper")
        func()
        print("complete wrapper")
    return inner_fun

#Required functionality
@deocrator_function
def noraml_func():
    print("Chocolate original")
    
#noraml_func = deocrator_function(noraml_func)
noraml_func()
# Out:
# front wrapper
# Chocolate original
# complete wrapper

# %%
#staticmethod
#classmethod
#abstractmethod

# %%
# importing libraries
import time
import math

# decorator to calculate duration
# taken by any function.
def calculate_time(func):

    # added arguments inside the inner1,
    # if function takes any arguments,
    # can be added like this.
    def inner1(*args, **kwargs):

        # storing time before function execution
        begin = time.time()
        print("The time before factorial calculation is ", begin)

        func(*args, **kwargs)
        # storing time after function execution
        end = time.time()
        print("The time after factorial calculation is ", end)

        print("Total time taken in : ", func.__name__, end - begin)

    return inner1



# this can be added to any function present,
# in this case to calculate a factorial
@calculate_time
def factorial(num):

	# sleep 2 seconds because it takes very less time
	# so that you can see the actual difference
	time.sleep(10)
	print(math.factorial(num))
    
#factorial = calculate_time(factorial)

# calling the function.
factorial(10)
# Out:
# The time before factorial calculation is  1639240861.838544
# 3628800
# The time after factorial calculation is  1639240871.8514414
# Total time taken in :  factorial 10.012897491455078

# %%
import time

print(time.time())

#number of seconds from Jan1 1970
# Out:
# 1639240669.5163167

# %%
#frozenset

#Data structure
#immutable Ds
#unique elements
#ordering NA 

#https://www.geeksforgeeks.org/frozenset-in-python/

#frozen set
#immutable iterable object ===> ordering, removes duplicates, immutable

x = [4,5,6,7,-1,2,3,9,1, 1]

z = frozenset(x)

print(z)
print(type(z))
# Out:
# frozenset({1, 2, 3, 4, 5, 6, 7, 9, -1})
# <class 'frozenset'>

# %%
#__main__


def func1(x,y):
    return x + y


func1()

#print(__name__)
#print("outside the function")

def main():
    func1(7,10)
    func2(8,20)

func1()


main()
    
if __name__ == "__main__":
    print(func1(3,4))
# Out:
# __main__
# outside the function
# 7

# %%
#any all ? ==> inbuilt functions


#any ==> OR gate
#all ===> ANd gate

x = 10 

if x >= 5 and x != 3 and x <= 20 and x ==10:
    print("equal to 10")

if all([x >= 5,x != 3,x <= 20,x ==10]):
    print("equal to 10")
# Out:
# equal to 10
# equal to 10

# %%
#sys module


#sys.argv
#sys.exit()

#time.time()
#time.sleep()

# %%
import sys
a = 10

b = 20

if a < b:
    print("a is less than b")
    sys.exit()
print("outside if stmt")

python_installed_path program_name.py
# Out:
# a is less than b
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\kanna\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#important modules

#sys.argv

# %%
#https://www.geeksforgeeks.org/how-to-use-sys-argv-in-python/

python_installed_path program_name.py param1="val1" param2="val2"

# %%
#https://docs.python.org/3/howto/argparse.html
